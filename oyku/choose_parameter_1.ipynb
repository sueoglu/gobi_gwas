# %%
# !pip install pandas-plink limix-lmm
# Out:
# Requirement already satisfied: pandas-plink in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (2.3.2)
# Requirement already satisfied: limix-lmm in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (0.1.2)
# Requirement already satisfied: cffi>=1.17 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandas-plink) (1.17.1)
# Requirement already satisfied: dask[dataframe] in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandas-plink) (2024.11.2)
# Requirement already satisfied: deprecated<2.0,>=1.2 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandas-plink) (1.3.1)
# Requirement already satisfied: numpy<2.0,>=1.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandas-plink) (1.26.4)
# Requirement already satisfied: pandas<3.0,>=2.2 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandas-plink) (2.3.3)
# Requirement already satisfied: pandera[dask,mypy] in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandas-plink) (0.27.0)
# Requirement already satisfied: tqdm<5.0,>=4.67 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandas-plink) (4.67.1)
# Requirement already satisfied: xarray in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandas-plink) (2025.6.1)
# Requirement already satisfied: zstandard<0.24,>=0.23 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandas-plink) (0.23.0)
# Requirement already satisfied: wrapt<3,>=1.10 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from deprecated<2.0,>=1.2->pandas-plink) (1.17.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandas<3.0,>=2.2->pandas-plink) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandas<3.0,>=2.2->pandas-plink) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandas<3.0,>=2.2->pandas-plink) (2025.2)
# Requirement already satisfied: scipy>=1.1.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from limix-lmm) (1.15.3)
# Requirement already satisfied: pytest>=3.6.3 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from limix-lmm) (9.0.1)
# Requirement already satisfied: limix-core>=1.0.2 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from limix-lmm) (1.0.2)
# Requirement already satisfied: matplotlib>=2.2.3 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from limix-lmm) (3.10.7)
# Requirement already satisfied: bgen-reader>=2.0.7 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from limix-lmm) (4.0.8)
# Requirement already satisfied: geno-sugar in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from limix-lmm) (0.1.1)
# Requirement already satisfied: appdirs>=1.4.3 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from bgen-reader>=2.0.7->limix-lmm) (1.4.4)
# Requirement already satisfied: cachetools>=3.1.1 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from bgen-reader>=2.0.7->limix-lmm) (6.2.2)
# Requirement already satisfied: cbgen>=1.0.1 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from bgen-reader>=2.0.7->limix-lmm) (1.0.5)
# Requirement already satisfied: requests>=1.25.8 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from bgen-reader>=2.0.7->limix-lmm) (2.32.5)
# Requirement already satisfied: texttable>=1.6.2 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from bgen-reader>=2.0.7->limix-lmm) (1.7.0)
# Requirement already satisfied: pooch in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from cbgen>=1.0.1->bgen-reader>=2.0.7->limix-lmm) (1.8.2)
# Requirement already satisfied: urllib3>=1.26 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from cbgen>=1.0.1->bgen-reader>=2.0.7->limix-lmm) (2.5.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from cffi>=1.17->pandas-plink) (2.22)
# Requirement already satisfied: click>=8.1 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from dask[dataframe]->pandas-plink) (8.3.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from dask[dataframe]->pandas-plink) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from dask[dataframe]->pandas-plink) (2025.10.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from dask[dataframe]->pandas-plink) (25.0)
# Requirement already satisfied: partd>=1.4.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from dask[dataframe]->pandas-plink) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from dask[dataframe]->pandas-plink) (6.0.3)
# Requirement already satisfied: toolz>=0.10.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from dask[dataframe]->pandas-plink) (1.1.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from dask[dataframe]->pandas-plink) (8.7.0)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from dask[array,bag,dataframe,delayed]>=2.12.0->bgen-reader>=2.0.7->limix-lmm) (1.1.19)
# Requirement already satisfied: pyarrow>=14.0.1 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from dask-expr<1.2,>=1.1->dask[array,bag,dataframe,delayed]>=2.12.0->bgen-reader>=2.0.7->limix-lmm) (22.0.0)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from importlib-metadata>=4.13.0->dask[dataframe]->pandas-plink) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from matplotlib>=2.2.3->limix-lmm) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from matplotlib>=2.2.3->limix-lmm) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from matplotlib>=2.2.3->limix-lmm) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from matplotlib>=2.2.3->limix-lmm) (1.4.9)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from matplotlib>=2.2.3->limix-lmm) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from matplotlib>=2.2.3->limix-lmm) (3.2.5)
# Requirement already satisfied: locket in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from partd>=1.4.0->dask[dataframe]->pandas-plink) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pytest>=3.6.3->limix-lmm) (1.3.0)
# Requirement already satisfied: iniconfig>=1.0.1 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pytest>=3.6.3->limix-lmm) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pytest>=3.6.3->limix-lmm) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pytest>=3.6.3->limix-lmm) (2.19.2)
# Requirement already satisfied: tomli>=1 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pytest>=3.6.3->limix-lmm) (2.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from exceptiongroup>=1->pytest>=3.6.3->limix-lmm) (4.15.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=2.2->pandas-plink) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from requests>=1.25.8->bgen-reader>=2.0.7->limix-lmm) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from requests>=1.25.8->bgen-reader>=2.0.7->limix-lmm) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from requests>=1.25.8->bgen-reader>=2.0.7->limix-lmm) (2025.11.12)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from geno-sugar->limix-lmm) (1.7.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from scikit-learn>=0.20.0->geno-sugar->limix-lmm) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from scikit-learn>=0.20.0->geno-sugar->limix-lmm) (3.6.0)
# Requirement already satisfied: pydantic in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandera[dask,mypy]->pandas-plink) (2.12.5)
# Requirement already satisfied: typeguard in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandera[dask,mypy]->pandas-plink) (4.4.4)
# Requirement already satisfied: typing_inspect>=0.6.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandera[dask,mypy]->pandas-plink) (0.9.0)
# Requirement already satisfied: pandas-stubs in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandera[dask,mypy]->pandas-plink) (2.3.2.250926)
# Requirement already satisfied: scipy-stubs in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandera[dask,mypy]->pandas-plink) (1.15.3.0)
# Requirement already satisfied: distributed in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandera[dask,mypy]->pandas-plink) (2024.11.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from typing_inspect>=0.6.0->pandera[dask,mypy]->pandas-plink) (1.1.0)
# Requirement already satisfied: jinja2>=2.10.3 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from distributed->pandera[dask,mypy]->pandas-plink) (3.0.3)
# Requirement already satisfied: msgpack>=1.0.2 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from distributed->pandera[dask,mypy]->pandas-plink) (1.1.2)
# Requirement already satisfied: psutil>=5.8.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from distributed->pandera[dask,mypy]->pandas-plink) (7.1.3)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from distributed->pandera[dask,mypy]->pandas-plink) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from distributed->pandera[dask,mypy]->pandas-plink) (3.2.2)
# Requirement already satisfied: tornado>=6.2.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from distributed->pandera[dask,mypy]->pandas-plink) (6.5.2)
# Requirement already satisfied: zict>=3.0.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from distributed->pandera[dask,mypy]->pandas-plink) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from jinja2>=2.10.3->distributed->pandera[dask,mypy]->pandas-plink) (3.0.3)
# Requirement already satisfied: types-pytz>=2022.1.1 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pandas-stubs->pandera[dask,mypy]->pandas-plink) (2025.2.0.20251108)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pooch->cbgen>=1.0.1->bgen-reader>=2.0.7->limix-lmm) (4.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pydantic->pandera[dask,mypy]->pandas-plink) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pydantic->pandera[dask,mypy]->pandas-plink) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from pydantic->pandera[dask,mypy]->pandas-plink) (0.4.2)
# Requirement already satisfied: optype>=0.9.3 in /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages (from scipy-stubs->pandera[dask,mypy]->pandas-plink) (0.9.3)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
from pandas_plink import read_plink
from limix_lmm import LMM
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm
from statsmodels.stats.multitest import multipletests
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
import scipy
import scipy.stats as st

if not hasattr(scipy, 'dot'):
    scipy.dot = np.dot
if not hasattr(scipy, 'einsum'):
    scipy.einsum = np.einsum
if not hasattr(scipy, 'log'):
    scipy.log = np.log
if not hasattr(scipy, 'sign'):
    scipy.sign = np.sign
if not hasattr(scipy, 'sqrt'):
    scipy.sqrt = np.sqrt

# %% [markdown]
# ### Preprocessing pipeline
#
# BFILE=/Users/oykusuoglu/gobi/gobi_gwas/oyku/data/ALL.chr22_GRCh38.genotypes.20170504
#
# OUTDIR=/Users/oykusuoglu/gobi/gobi_gwas/oyku/data/qc
#
# mkdir -p "$OUTDIR"
#
#
# plink --bfile "$BFILE" --freq --missing --out "$OUTDIR"/initial_qc
#
#
# Preprocessing
#
# We only kept SNP like variants (single base substitutions), dropped variants with missing rate > 0.02 and minor allele frequency < 0.01 to keep only commons, and also variants that have extreme deviations that are caused by noise rather than signal
#
# (filtered data set written as a new bed/bim/fam)
#
#
# plink --bfile "$BFILE" \
#   --snps-only \
#   --geno 0.02 \
#   --maf 0.01 \
#   --hwe 1e-6 \
#   --make-bed \
#   --out "$OUTDIR"/chr22_step1_common
#
#
# check if there are duplicate variant ids
#
# plink --bfile "$OUTDIR"/chr22_step1_common \
#   --list-duplicate-vars ids-only suppress-first \
#   --out "$OUTDIR"/dupcheck
#
# wc -l "$OUTDIR"/dupcheck.dupvar
#
# there were no duplicates (0)
#
# plink --bfile "$OUTDIR"/chr22_step1_common \
#   --exclude "$OUTDIR"/dupcheck.dupvar \
#   --make-bed \
#   --out "$OUTDIR"/chr22_step2_nodup
#
# sample level missingness, none was filtered (both chr22_step2_nodup.fam and chr22_step3_sampleqc.fam are same size 2504)
#
# plink --bfile "$OUTDIR"/chr22_step2_nodup \
#   --mind 0.02 \
#   --make-bed \
#   --out "$OUTDIR"/chr22_step3_sampleqc

# %% [markdown]
# INITIAL:
#
# Number of variants: 109827
#
# Number of samples: 2504
#
# AFTER QC:
#
# Number of variants: 59743
#
# Number of samples: 2504

# %%
bfile = 'data/qc/chr22_step3_sampleqc'
bim, fam, G = read_plink(bfile)
# Out:
# Mapping files: 100%|██████████| 3/3 [00:00<00:00, 47.76it/s]
# /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages/pandera/_pandas_deprecated.py:146: FutureWarning: Importing pandas-specific classes and functions from the
# top-level pandera module will be **removed in a future version of pandera**.
# If you're using pandera to validate pandas objects, we highly recommend updating
# your import:
#
# ```
# # old import
# import pandera as pa
#
# # new import
# import pandera.pandas as pa
# ```
#
# If you're using pandera to validate objects from other compatible libraries
# like pyspark or polars, see the supported libraries section of the documentation
# for more information on how to import pandera:
#
# https://pandera.readthedocs.io/en/stable/supported_libraries.html
#
# To disable this warning, set the environment variable:
#
# ```
# export DISABLE_PANDERA_IMPORT_WARNING=True
# ```
#
#   warnings.warn(_future_warning, FutureWarning)

# %%
X_real = G.compute().T

# %% [markdown]
# Standardize the genotype matrix, so that all SNPs are on the same scale, 3 variants were dropped, which had a standard deviation equals to 0 among all individuals. (bim annotation table must be also updated)

# %%
#whole chromosome 22

mu_full = X_real.mean(axis=0)
sd_full = X_real.std(axis=0, ddof=0)
keep_full = sd_full > 1e-12
keep_idx  = np.where(keep_full)[0] 
standardized_X = (X_real[:, keep_full] - mu_full[keep_full]) / sd_full[keep_full]

# %%
# bim data for variants that werent dropped after the standardization
bim_kept = bim.iloc[keep_idx].copy().reset_index(drop=True)

bim_kept["orig_bim_idx"] = keep_idx

# %%
standardized_X.shape
# Out:
# (2504, 59740)

# %%
def simulate_pheno(X, idx_caus, var_expl, rng, direction=None):
    # Ensure that the number of causal variant indices matches the number of variances explained.
    assert len(idx_caus) == len(var_expl)

    # If no direction is provided, randomly assign a positive or negative direction for each causal variant.
    if direction is None:
        direction = 2. * (rng.random(len(idx_caus)) > 0.5) - 1.
    # Ensure that the number of directions matches the number of causal variant indices.
    assert len(idx_caus) == len(direction)

    # Compute the remaining variance after accounting for the variance explained by the causal variants.
    ve = 1 - var_expl.sum()
    # Ensure that the total variance explained by causal variants is less than 1.
    assert ve > 0, 'sum(var_expl) should be < 1'

    # Compute the effect sizes for the causal variants based on the variance they explain and their direction.
    beta = np.sqrt(var_expl) * direction

    # Extract the columns of X corresponding to the causal variants and standardize them.
    Xc = X[:, idx_caus]
    Xc = (Xc - Xc.mean(0)) / Xc.std(0)

    # Compute the genetic component of the phenotype.
    yg = Xc.dot(beta)[:, None]
    # Compute the noise component of the phenotype.
    yn = np.sqrt(ve) * rng.standard_normal((X.shape[0], 1))

    # Sum the genetic and noise components to get the simulated phenotype.
    y = yg + yn

    # Initialize the real effect sizes for all variants in X as zeros.
    beta_real = np.zeros(X.shape[1])
    # Update the real effect sizes for the causal variants.
    beta_real[idx_caus] = beta

    # Standardize the phenotypic values to have mean 0 and standard deviation 1.
    ystd = y.std()
    y = (y - y.mean()) / ystd
    # Adjust the real effect sizes accordingly after standardizing y.
    beta_real = beta_real / ystd

    return y, beta_real

# %%
def qq_plot(p_values, title):
    """
    Create a QQ plot given a list of p-values.

    Parameters:
    - p_values: list of p-values
    - title: title for the plot
    """

    # Sort p-values
    observed = -np.log10(np.sort(p_values))
    expected = -np.log10(np.arange(1, len(p_values) + 1) / (len(p_values) + 2))

    # Create the QQ plot
    plt.scatter(expected, observed, marker='.')
    plt.plot([0, max(expected)], [0, max(expected)], color='red', linestyle='--')
    plt.xlabel('Expected -log10(P-value)')
    plt.ylabel('Observed -log10(P-value)')
    plt.title(title)

# %%
m = np.arange(10, 101, 10)
heritability_vals = np.linspace(0.1, 0.6, 6).astype(np.float64)

# %%
from pathlib import Path
base_dir = Path("/Users/oykusuoglu/gobi/gobi_gwas/oyku/plots")

# %%
for heritability in heritability_vals:
    for count_causal in m:
        # Phenotype simulation
        rng = np.random.default_rng(42)
        idx_caus_loop = rng.choice(standardized_X.shape[1], size=count_causal, replace=False)
        var_expl_loop = np.repeat(heritability/count_causal, count_causal)

        y_loop, beta_real_loop = simulate_pheno(standardized_X, idx_caus_loop, var_expl_loop, rng)

        # Merging PCs with phenotype
        pheno = fam[["fid","iid"]].copy()
        pheno.columns = ["FID","IID"]
        pheno["y"] = y_loop.reshape(-1)

        pcs = pd.read_csv("data/pca/chr22_pca.eigenvec", sep=r"\s+", header=None, engine="python")
        pcs.columns = ["FID","IID"] + [f"PC{i}" for i in range(1, pcs.shape[1]-1)]

        df = pheno.merge(pcs, on=["FID","IID"], how="inner", validate="one_to_one")
        k = 10
        F = np.column_stack([np.ones((df.shape[0], 1)), df[[f"PC{i}" for i in range(1, k+1)]].to_numpy()])

        # Training split
        X_train, X_test, y_train, y_test, F_train, F_test = train_test_split(
                                                            standardized_X, y_loop, F,
                                                            test_size=0.3,
                                                            random_state=42,
                                                            shuffle=True
                                                                        )
        # GWAS
        lmm = LMM(y_train, F_train)
        lmm.process(X_train)
        pv = lmm.getPv()
        beta = lmm.getBetaSNP()
        beta_ste = lmm.getBetaSNPste()

        outdir = base_dir / f"h2_{heritability}_causal_vars{count_causal}"
        outdir.mkdir(parents=True, exist_ok=True)

        # plotting
        fig = plt.figure()
        qq_plot(pv, f'QQ Plot for heritability: {heritability} number of causal variants: {count_causal}')
        fig.tight_layout()
        fig.savefig(outdir / f"qq_h2_{heritability}_causal_vars{count_causal}.png", dpi=300, bbox_inches="tight")
        plt.close(fig)

        x = bim_kept['pos'].values
        fig2 = plt.figure(figsize=(10, 6))
        ax1 = fig2.add_subplot(2, 1, 1)
        ax2 = fig2.add_subplot(2, 1, 2, sharex=ax1)

        ax1.set_title(f"Real effect size for heritability: {heritability} number of causal variants: {count_causal}")
        ax1.plot(x, beta_real_loop, ".k")
        ax1.set_ylabel("eff size")

        ax2.set_title(f"GWAS results for heritability: {heritability} number of causal variants: {count_causal}")
        ax2.plot(x, -np.log10(pv), ".k")
        ax2.set_ylabel(r"-log$_{10}$ P")
        ax2.set_xlabel("position")

        fig2.tight_layout()
        fig2.savefig(outdir / f"effects_gwas_h2{heritability}_causal_vars{count_causal}.png",
                    dpi=300, bbox_inches="tight")
        plt.close(fig2)
# Out:
# /opt/anaconda3/envs/gobi_venv/lib/python3.10/site-packages/limix_lmm/lmm_core.py:322: RuntimeWarning: divide by zero encountered in divide
#   ste = beta / z

# %% [markdown]
# ### Phase 2: GWAS / Feature Selection

# %% [markdown]
# #### 3. Clumping using PLINK

# %% [markdown]
# First create a file with SNP ids and their corresponding p-values

# %%
gwas_for_clump = pd.DataFrame({
    "SNP": bim_kept["snp"].astype(str),   
    "P": np.asarray(pv, dtype=float)
})
gwas_for_clump.to_csv("gwas_for_clump.txt", sep="\t", index=False)
